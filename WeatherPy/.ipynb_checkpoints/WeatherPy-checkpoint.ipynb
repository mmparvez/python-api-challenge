# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Analysis:
# 1. Weather becomes warmer as we approach the equater. From the plot, the northern hemispher seems to be slightly warmer.
# 2. There is not much relationship between latitude and wind speed.
# 3. There is not much relationship between latitude and cloudiness.
# 4. There is not much relationship between latitude and humidity.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 614

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# Set up url for API call
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
#Create a Dataframe to hold the data
cities_df = pd.DataFrame(cities, columns = ["City"])
cities_df["Lat"] = ""
cities_df["Lng"] = ""
cities_df["Max Temp"] = ""
cities_df["Humidity"] = ""
cities_df["Cloudiness"] = ""
cities_df["Wind Speed"] = ""
cities_df["Country"] = ""
cities_df["Date"] = ""
record_count = 1
set_count = 1

# Loop through the list of cities and perform a request for data on each city
# This will take a while to run
print("Beginning Data Retrieval     ")
print("-----------------------------")
for index, row in cities_df.iterrows():
    if (record_count % 50 == 0 and record_count >= 50):
        set_count += 1
        record_count = 0
    city = row["City"]
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    record_count += 1

    #response = requests.get(query_url + city).json()
    #Use try/except to skip any cities with errors
    try:
        response = requests.get(query_url + city).json()
        cities_df.loc[index, "Lat"] = response["coord"]["lat"]
        cities_df.loc[index, "Lng"] = response["coord"]["lon"]
        cities_df.loc[index, "Max Temp"] = response["main"]["temp_max"]
        cities_df.loc[index, "Humidity"] = response["main"]["humidity"]
        cities_df.loc[index, "Cloudiness"] = response["clouds"]["all"]
        cities_df.loc[index, "Wind Speed"] = response["wind"]["speed"]
        cities_df.loc[index, "Country"] = response["sys"]["country"]
        cities_df.loc[index, "Date"] = response["dt"]
    except :
        print("City not found. Skipping...")
        pass
    
print(f'{cities_df.shape} Data Retrieval Complete')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | morant bay
# Processing Record 2 of Set 1 | portland
# Processing Record 3 of Set 1 | batagay
# Processing Record 4 of Set 1 | los llanos de aridane
# Processing Record 5 of Set 1 | chuy
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | kavieng
# Processing Record 9 of Set 1 | tasiilaq
# Processing Record 10 of Set 1 | paducah
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | port alfred
# Processing Record 14 of Set 1 | ostrovnoy
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | bluff
# Processing Record 17 of Set 1 | katsuura
# Processing Record 18 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 1 | nikolskoye
# Processing Record 20 of Set 1 | flin flon
# Processing Record 21 of Set 1 | okhotsk
# Processing Record 22 of Set 1 | carutapera
# Processing Record 23 of Set 1 | conneaut
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | omsukchan
# Processing Record 26 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | nara
# Processing Record 29 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 1 | faanui
# Processing Record 31 of Set 1 | timmins
# Processing Record 32 of Set 1 | castro
# Processing Record 33 of Set 1 | talnakh
# Processing Record 34 of Set 1 | shostka
# Processing Record 35 of Set 1 | gorontalo
# Processing Record 36 of Set 1 | ancud
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | sinaloa
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 41 of Set 1 | joniskelis
# Processing Record 42 of Set 1 | tiarei
# Processing Record 43 of Set 1 | mahebourg
# Processing Record 44 of Set 1 | ode
# Processing Record 45 of Set 1 | pevek
# Processing Record 46 of Set 1 | iqaluit
# Processing Record 47 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 48 of Set 1 | padang
# Processing Record 49 of Set 1 | bambous virieux
# Processing Record 0 of Set 2 | arlit
# Processing Record 1 of Set 2 | phan thiet
# Processing Record 2 of Set 2 | havoysund
# Processing Record 3 of Set 2 | timiryazevskiy
# Processing Record 4 of Set 2 | vanavara
# Processing Record 5 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | cartagena del chaira
# Processing Record 8 of Set 2 | codrington
# Processing Record 9 of Set 2 | mar del plata
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | hermanus
# Processing Record 12 of Set 2 | vreed en hoop
# City not found. Skipping...
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | dupnica
# City not found. Skipping...
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | lagoa
# Processing Record 17 of Set 2 | ushuaia
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | yerofey pavlovich
# Processing Record 20 of Set 2 | avarua
# Processing Record 21 of Set 2 | rundu
# Processing Record 22 of Set 2 | kosh-agach
# Processing Record 23 of Set 2 | mataura
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | mao
# Processing Record 26 of Set 2 | nhulunbuy
# Processing Record 27 of Set 2 | east london
# Processing Record 28 of Set 2 | hilo
# Processing Record 29 of Set 2 | caravelas
# Processing Record 30 of Set 2 | victoria
# Processing Record 31 of Set 2 | alofi
# Processing Record 32 of Set 2 | natal
# Processing Record 33 of Set 2 | lamu
# Processing Record 34 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 2 | capao da canoa
# Processing Record 36 of Set 2 | dakoro
# Processing Record 37 of Set 2 | upernavik
# Processing Record 38 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 2 | ahipara
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | torbay
# Processing Record 42 of Set 2 | thompson
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | kruisfontein
# Processing Record 45 of Set 2 | chiautla
# Processing Record 46 of Set 2 | nokaneng
# Processing Record 47 of Set 2 | kutoarjo
# Processing Record 48 of Set 2 | constitucion
# Processing Record 49 of Set 2 | talara
# Processing Record 0 of Set 3 | shalakusha
# Processing Record 1 of Set 3 | ouesso
# Processing Record 2 of Set 3 | ilulissat
# Processing Record 3 of Set 3 | vestmannaeyjar
# Processing Record 4 of Set 3 | mandawar
# Processing Record 5 of Set 3 | honningsvag
# Processing Record 6 of Set 3 | rawson
# Processing Record 7 of Set 3 | dikson
# Processing Record 8 of Set 3 | ganzhou
# Processing Record 9 of Set 3 | deep river
# Processing Record 10 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 3 | guliston
# Processing Record 12 of Set 3 | deputatskiy
# Processing Record 13 of Set 3 | te anau
# Processing Record 14 of Set 3 | balkhash
# Processing Record 15 of Set 3 | narsaq
# Processing Record 16 of Set 3 | lorengau
# Processing Record 17 of Set 3 | tura
# Processing Record 18 of Set 3 | moron
# Processing Record 19 of Set 3 | tuatapere
# Processing Record 20 of Set 3 | opuwo
# Processing Record 21 of Set 3 | la primavera
# Processing Record 22 of Set 3 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 23 of Set 3 | arroyo
# Processing Record 24 of Set 3 | mount gambier
# Processing Record 25 of Set 3 | mutsamudu
# City not found. Skipping...
# Processing Record 26 of Set 3 | linhares
# Processing Record 27 of Set 3 | ugoofaaru
# Processing Record 28 of Set 3 | sao felix do xingu
# Processing Record 29 of Set 3 | kalemie
# Processing Record 30 of Set 3 | clyde river
# Processing Record 31 of Set 3 | pisco
# Processing Record 32 of Set 3 | chokurdakh
# Processing Record 33 of Set 3 | basco
# Processing Record 34 of Set 3 | boa vista
# Processing Record 35 of Set 3 | myaundzha
# Processing Record 36 of Set 3 | uyemskiy
# Processing Record 37 of Set 3 | vao
# Processing Record 38 of Set 3 | kupang
# Processing Record 39 of Set 3 | sembe
# Processing Record 40 of Set 3 | pietersburg
# Processing Record 41 of Set 3 | kavaratti
# Processing Record 42 of Set 3 | lalibela
# Processing Record 43 of Set 3 | lavrentiya
# Processing Record 44 of Set 3 | kodiak
# Processing Record 45 of Set 3 | kaitangata
# Processing Record 46 of Set 3 | vaini
# Processing Record 47 of Set 3 | bundaberg
# Processing Record 48 of Set 3 | saint-philippe
# Processing Record 49 of Set 3 | rocha
# Processing Record 0 of Set 4 | troitskoye
# Processing Record 1 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 4 | mushie
# Processing Record 3 of Set 4 | abu samrah
# Processing Record 4 of Set 4 | ponta do sol
# Processing Record 5 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 6 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 4 | chhabra
# Processing Record 8 of Set 4 | bredasdorp
# Processing Record 9 of Set 4 | saint anthony
# Processing Record 10 of Set 4 | kloulklubed
# Processing Record 11 of Set 4 | labuhan
# Processing Record 12 of Set 4 | geraldton
# Processing Record 13 of Set 4 | tilichiki
# Processing Record 14 of Set 4 | kempen
# Processing Record 15 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 4 | tuy hoa
# Processing Record 17 of Set 4 | saldanha
# Processing Record 18 of Set 4 | saskylakh
# Processing Record 19 of Set 4 | ekhabi
# Processing Record 20 of Set 4 | gberia fotombu
# Processing Record 21 of Set 4 | severobaykalsk
# Processing Record 22 of Set 4 | kokopo
# Processing Record 23 of Set 4 | kahului
# Processing Record 24 of Set 4 | lebu
# Processing Record 25 of Set 4 | ust-uda
# Processing Record 26 of Set 4 | ilam
# Processing Record 27 of Set 4 | ixtapa
# Processing Record 28 of Set 4 | northam
# Processing Record 29 of Set 4 | cabedelo
# Processing Record 30 of Set 4 | khatanga
# Processing Record 31 of Set 4 | obihiro
# Processing Record 32 of Set 4 | terrell
# Processing Record 33 of Set 4 | belmopan
# Processing Record 34 of Set 4 | chapais
# Processing Record 35 of Set 4 | lata
# Processing Record 36 of Set 4 | beringovskiy
# Processing Record 37 of Set 4 | biritiba-mirim
# Processing Record 38 of Set 4 | oranjestad
# Processing Record 39 of Set 4 | airai
# Processing Record 40 of Set 4 | mayo
# Processing Record 41 of Set 4 | butaritari
# Processing Record 42 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 4 | kysyl-syr
# Processing Record 44 of Set 4 | banyo
# Processing Record 45 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 46 of Set 4 | rancho santa margarita
# Processing Record 47 of Set 4 | puerto ayora
# Processing Record 48 of Set 4 | villa nueva
# Processing Record 49 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 0 of Set 5 | kirakira
# Processing Record 1 of Set 5 | sinnamary
# Processing Record 2 of Set 5 | barrhead
# Processing Record 3 of Set 5 | killybegs
# Processing Record 4 of Set 5 | liberal
# Processing Record 5 of Set 5 | ribeira grande
# Processing Record 6 of Set 5 | mentok
# City not found. Skipping...
# Processing Record 7 of Set 5 | yellowknife
# Processing Record 8 of Set 5 | norman wells
# Processing Record 9 of Set 5 | naryan-mar
# Processing Record 10 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 5 | la asuncion
# Processing Record 12 of Set 5 | ponta delgada
# Processing Record 13 of Set 5 | muddebihal
# Processing Record 14 of Set 5 | cockburn town
# Processing Record 15 of Set 5 | vardo
# Processing Record 16 of Set 5 | pontianak
# Processing Record 17 of Set 5 | hovd
# Processing Record 18 of Set 5 | cap malheureux
# Processing Record 19 of Set 5 | adrar
# Processing Record 20 of Set 5 | olafsvik
# Processing Record 21 of Set 5 | siparia
# Processing Record 22 of Set 5 | ginda
# Processing Record 23 of Set 5 | ketchikan
# Processing Record 24 of Set 5 | naugarzan
# City not found. Skipping...
# Processing Record 25 of Set 5 | lincoln
# Processing Record 26 of Set 5 | porto novo
# Processing Record 27 of Set 5 | bandarbeyla
# Processing Record 28 of Set 5 | bamboo
# Processing Record 29 of Set 5 | maloy
# Processing Record 30 of Set 5 | sioux lookout
# Processing Record 31 of Set 5 | sangueya
# Processing Record 32 of Set 5 | ariano irpino
# Processing Record 33 of Set 5 | port blair
# Processing Record 34 of Set 5 | srednekolymsk
# Processing Record 35 of Set 5 | batemans bay
# Processing Record 36 of Set 5 | tela
# Processing Record 37 of Set 5 | cherskiy
# Processing Record 38 of Set 5 | paamiut
# Processing Record 39 of Set 5 | baoning
# Processing Record 40 of Set 5 | cumra
# Processing Record 41 of Set 5 | shu
# Processing Record 42 of Set 5 | husavik
# Processing Record 43 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 44 of Set 5 | tazovskiy
# Processing Record 45 of Set 5 | nyrob
# Processing Record 46 of Set 5 | tuktoyaktuk
# Processing Record 47 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 5 | afsin
# Processing Record 49 of Set 5 | shache
# Processing Record 0 of Set 6 | luderitz
# Processing Record 1 of Set 6 | antonovo
# Processing Record 2 of Set 6 | bonthe
# Processing Record 3 of Set 6 | isangel
# Processing Record 4 of Set 6 | rumphi
# Processing Record 5 of Set 6 | cap-chat
# Processing Record 6 of Set 6 | vaitape
# Processing Record 7 of Set 6 | tyulgan
# Processing Record 8 of Set 6 | pangkalanbuun
# Processing Record 9 of Set 6 | muros
# Processing Record 10 of Set 6 | sitka
# Processing Record 11 of Set 6 | hasaki
# Processing Record 12 of Set 6 | zapolyarnyy
# Processing Record 13 of Set 6 | longyearbyen
# Processing Record 14 of Set 6 | leningradskiy
# Processing Record 15 of Set 6 | beloha
# Processing Record 16 of Set 6 | hualmay
# Processing Record 17 of Set 6 | filadelfia
# Processing Record 18 of Set 6 | tibati
# Processing Record 19 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 20 of Set 6 | kharian
# Processing Record 21 of Set 6 | contamana
# Processing Record 22 of Set 6 | jacareacanga
# Processing Record 23 of Set 6 | zinder
# Processing Record 24 of Set 6 | san jose de ocoa
# Processing Record 25 of Set 6 | provideniya
# Processing Record 26 of Set 6 | hauterive
# Processing Record 27 of Set 6 | hay river
# Processing Record 28 of Set 6 | severo-kurilsk
# Processing Record 29 of Set 6 | andrelandia
# Processing Record 30 of Set 6 | nam tha
# City not found. Skipping...
# Processing Record 31 of Set 6 | saint-francois
# Processing Record 32 of Set 6 | pangnirtung
# Processing Record 33 of Set 6 | laguna
# Processing Record 34 of Set 6 | bermejo
# Processing Record 35 of Set 6 | mogadishu
# Processing Record 36 of Set 6 | poum
# Processing Record 37 of Set 6 | broken hill
# Processing Record 38 of Set 6 | san miguel
# Processing Record 39 of Set 6 | lompoc
# Processing Record 40 of Set 6 | aksu
# Processing Record 41 of Set 6 | bethel
# Processing Record 42 of Set 6 | turukhansk
# Processing Record 43 of Set 6 | kidal
# Processing Record 44 of Set 6 | vila velha
# Processing Record 45 of Set 6 | meulaboh
# Processing Record 46 of Set 6 | nanortalik
# Processing Record 47 of Set 6 | kodinsk
# Processing Record 48 of Set 6 | whitehorse
# Processing Record 49 of Set 6 | ramgarh
# Processing Record 0 of Set 7 | saint-pierre
# Processing Record 1 of Set 7 | miles city
# Processing Record 2 of Set 7 | fukuma
# Processing Record 3 of Set 7 | gat
# Processing Record 4 of Set 7 | concordia
# Processing Record 5 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 7 | esil
# Processing Record 7 of Set 7 | hofn
# Processing Record 8 of Set 7 | marrakesh
# Processing Record 9 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 7 | shelburne
# Processing Record 11 of Set 7 | bengkulu
# Processing Record 12 of Set 7 | chumikan
# Processing Record 13 of Set 7 | vallenar
# Processing Record 14 of Set 7 | dongsheng
# Processing Record 15 of Set 7 | chernyanka
# Processing Record 16 of Set 7 | iskateley
# Processing Record 17 of Set 7 | bulgan
# Processing Record 18 of Set 7 | tiksi
# Processing Record 19 of Set 7 | amuntai
# Processing Record 20 of Set 7 | esperance
# Processing Record 21 of Set 7 | valleyview
# Processing Record 22 of Set 7 | vila franca do campo
# Processing Record 23 of Set 7 | roald
# Processing Record 24 of Set 7 | kieta
# Processing Record 25 of Set 7 | guerrero negro
# Processing Record 26 of Set 7 | great falls
# Processing Record 27 of Set 7 | hammerfest
# Processing Record 28 of Set 7 | lazaro cardenas
# Processing Record 29 of Set 7 | susanville
# Processing Record 30 of Set 7 | ternate
# Processing Record 31 of Set 7 | namibe
# Processing Record 32 of Set 7 | tanete
# Processing Record 33 of Set 7 | aktau
# Processing Record 34 of Set 7 | ewo
# Processing Record 35 of Set 7 | santo andre
# Processing Record 36 of Set 7 | liepaja
# Processing Record 37 of Set 7 | genhe
# Processing Record 38 of Set 7 | anadyr
# Processing Record 39 of Set 7 | tono
# Processing Record 40 of Set 7 | urussanga
# Processing Record 41 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 42 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 7 | carnarvon
# Processing Record 45 of Set 7 | mayumba
# Processing Record 46 of Set 7 | baoqing
# Processing Record 47 of Set 7 | flinders
# Processing Record 48 of Set 7 | eureka
# Processing Record 49 of Set 7 | khakhea
# Processing Record 0 of Set 8 | aykhal
# Processing Record 1 of Set 8 | goure
# Processing Record 2 of Set 8 | kalmunai
# Processing Record 3 of Set 8 | gbadolite
# Processing Record 4 of Set 8 | margate
# Processing Record 5 of Set 8 | touros
# Processing Record 6 of Set 8 | sabang
# Processing Record 7 of Set 8 | sao filipe
# Processing Record 8 of Set 8 | shebunino
# Processing Record 9 of Set 8 | chirongui
# Processing Record 10 of Set 8 | esperantinopolis
# Processing Record 11 of Set 8 | sainte-rose
# Processing Record 12 of Set 8 | coquimbo
# Processing Record 13 of Set 8 | port hardy
# Processing Record 14 of Set 8 | soledade
# Processing Record 15 of Set 8 | mpika
# Processing Record 16 of Set 8 | bousso
# Processing Record 17 of Set 8 | emerald
# Processing Record 18 of Set 8 | boksitogorsk
# Processing Record 19 of Set 8 | kembe
# Processing Record 20 of Set 8 | kirkuk
# Processing Record 21 of Set 8 | comodoro rivadavia
# Processing Record 22 of Set 8 | shingu
# Processing Record 23 of Set 8 | hami
# Processing Record 24 of Set 8 | alice springs
# Processing Record 25 of Set 8 | riyadh
# Processing Record 26 of Set 8 | hamilton
# Processing Record 27 of Set 8 | ulaanbaatar
# Processing Record 28 of Set 8 | naze
# Processing Record 29 of Set 8 | noumea
# Processing Record 30 of Set 8 | neuquen
# Processing Record 31 of Set 8 | qaqortoq
# Processing Record 32 of Set 8 | broome
# Processing Record 33 of Set 8 | fraga
# Processing Record 34 of Set 8 | junin
# Processing Record 35 of Set 8 | lethem
# Processing Record 36 of Set 8 | stokmarknes
# Processing Record 37 of Set 8 | dalinghe
# City not found. Skipping...
# Processing Record 38 of Set 8 | canon city
# Processing Record 39 of Set 8 | kargasok
# Processing Record 40 of Set 8 | katobu
# Processing Record 41 of Set 8 | nelson
# Processing Record 42 of Set 8 | jalu
# Processing Record 43 of Set 8 | leh
# Processing Record 44 of Set 8 | peniche
# Processing Record 45 of Set 8 | cabo san lucas
# Processing Record 46 of Set 8 | huron
# Processing Record 47 of Set 8 | sola
# Processing Record 48 of Set 8 | hervey bay
# Processing Record 49 of Set 8 | abu kamal
# Processing Record 0 of Set 9 | evensk
# Processing Record 1 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 2 of Set 9 | san patricio
# Processing Record 3 of Set 9 | senekal
# Processing Record 4 of Set 9 | fortuna
# Processing Record 5 of Set 9 | bilibino
# Processing Record 6 of Set 9 | yaan
# Processing Record 7 of Set 9 | murchison
# Processing Record 8 of Set 9 | tatarskaya kargala
# Processing Record 9 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 10 of Set 9 | bageshwar
# Processing Record 11 of Set 9 | puerto escondido
# Processing Record 12 of Set 9 | farah
# Processing Record 13 of Set 9 | singuilucan
# Processing Record 14 of Set 9 | cidreira
# Processing Record 15 of Set 9 | pathein
# Processing Record 16 of Set 9 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 9 | pedreiras
# Processing Record 18 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 19 of Set 9 | bathsheba
# Processing Record 20 of Set 9 | nao-me-toque
# City not found. Skipping...
# Processing Record 21 of Set 9 | grand gaube
# Processing Record 22 of Set 9 | dakar
# Processing Record 23 of Set 9 | nioro
# Processing Record 24 of Set 9 | orje
# Processing Record 25 of Set 9 | dwarka
# Processing Record 26 of Set 9 | perbaungan
# Processing Record 27 of Set 9 | bouillante
# Processing Record 28 of Set 9 | norsup
# Processing Record 29 of Set 9 | creston
# Processing Record 30 of Set 9 | coihaique
# Processing Record 31 of Set 9 | souillac
# Processing Record 32 of Set 9 | gabu
# Processing Record 33 of Set 9 | maues
# Processing Record 34 of Set 9 | pio xii
# Processing Record 35 of Set 9 | porto velho
# Processing Record 36 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 37 of Set 9 | tando muhammad khan
# Processing Record 38 of Set 9 | bitung
# Processing Record 39 of Set 9 | hambantota
# Processing Record 40 of Set 9 | springdale
# Processing Record 41 of Set 9 | suntar
# Processing Record 42 of Set 9 | san rafael
# Processing Record 43 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 44 of Set 9 | bojonegoro
# Processing Record 45 of Set 9 | yoichi
# Processing Record 46 of Set 9 | solano
# Processing Record 47 of Set 9 | fort saint john
# City not found. Skipping...
# Processing Record 48 of Set 9 | stryn
# Processing Record 49 of Set 9 | san cristobal
# Processing Record 0 of Set 10 | diu
# Processing Record 1 of Set 10 | ipameri
# Processing Record 2 of Set 10 | surab
# Processing Record 3 of Set 10 | punta alta
# Processing Record 4 of Set 10 | namatanai
# Processing Record 5 of Set 10 | santa rosa
# Processing Record 6 of Set 10 | awjilah
# Processing Record 7 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 10 | kudahuvadhoo
# Processing Record 9 of Set 10 | kattivakkam
# Processing Record 10 of Set 10 | grindavik
# Processing Record 11 of Set 10 | korla
# Processing Record 12 of Set 10 | west monroe
# Processing Record 13 of Set 10 | sucre
# Processing Record 14 of Set 10 | wiwili
# Processing Record 15 of Set 10 | port-gentil
# Processing Record 16 of Set 10 | freeport
# Processing Record 17 of Set 10 | antipino
# Processing Record 18 of Set 10 | atambua
# Processing Record 19 of Set 10 | praia
# Processing Record 20 of Set 10 | klaksvik
# Processing Record 21 of Set 10 | nouadhibou
# Processing Record 22 of Set 10 | la plata
# Processing Record 23 of Set 10 | marawi
# Processing Record 24 of Set 10 | tunga
# Processing Record 25 of Set 10 | saint-georges
# Processing Record 26 of Set 10 | ust-maya
# Processing Record 27 of Set 10 | calderitas
# Processing Record 28 of Set 10 | lasa
# Processing Record 29 of Set 10 | yeppoon
# Processing Record 30 of Set 10 | townsville
# Processing Record 31 of Set 10 | mochudi
# Processing Record 32 of Set 10 | vitoria de santo antao
# Processing Record 33 of Set 10 | san luis
# Processing Record 34 of Set 10 | faya
# Processing Record 35 of Set 10 | ca mau
# Processing Record 36 of Set 10 | yeniseysk
# Processing Record 37 of Set 10 | aklavik
# Processing Record 38 of Set 10 | bobonong
# City not found. Skipping...
# Processing Record 39 of Set 10 | penha
# Processing Record 40 of Set 10 | dukat
# Processing Record 41 of Set 10 | fayaoue
# Processing Record 42 of Set 10 | atar
# Processing Record 43 of Set 10 | imbituba
# Processing Record 44 of Set 10 | henties bay
# Processing Record 45 of Set 10 | paripiranga
# Processing Record 46 of Set 10 | makat
# Processing Record 47 of Set 10 | coaldale
# Processing Record 48 of Set 10 | apia
# Processing Record 49 of Set 10 | ballina
# Processing Record 0 of Set 11 | stawell
# Processing Record 1 of Set 11 | zhezkazgan
# Processing Record 2 of Set 11 | wau
# Processing Record 3 of Set 11 | dingle
# Processing Record 4 of Set 11 | marsh harbour
# Processing Record 5 of Set 11 | sur
# Processing Record 6 of Set 11 | san vicente de canete
# Processing Record 7 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 8 of Set 11 | itarema
# Processing Record 9 of Set 11 | chiredzi
# Processing Record 10 of Set 11 | xichang
# Processing Record 11 of Set 11 | umm kaddadah
# Processing Record 12 of Set 11 | rorvik
# Processing Record 13 of Set 11 | phra pradaeng
# Processing Record 14 of Set 11 | usinsk
# Processing Record 15 of Set 11 | linguere
# Processing Record 16 of Set 11 | churapcha
# Processing Record 17 of Set 11 | fort nelson
# Processing Record 18 of Set 11 | doka
# Processing Record 19 of Set 11 | ponca city
# Processing Record 20 of Set 11 | wanning
# Processing Record 21 of Set 11 | port hedland
# Processing Record 22 of Set 11 | acari
# Processing Record 23 of Set 11 | manavalakurichi
# Processing Record 24 of Set 11 | ketchenery
# City not found. Skipping...
# Processing Record 25 of Set 11 | talcahuano
# Processing Record 26 of Set 11 | yar-sale
# Processing Record 27 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 28 of Set 11 | yulara
# Processing Record 29 of Set 11 | frontera
# Processing Record 30 of Set 11 | launceston
# Processing Record 31 of Set 11 | mandera
# Processing Record 32 of Set 11 | rovaniemi
# Processing Record 33 of Set 11 | limbe
# Processing Record 34 of Set 11 | mount isa
# Processing Record 35 of Set 11 | acandi
# Processing Record 36 of Set 11 | dzhebariki-khaya
# Processing Record 37 of Set 11 | kisangani
# Processing Record 38 of Set 11 | balikpapan
# Processing Record 39 of Set 11 | muana
# Processing Record 40 of Set 11 | hohhot
# Processing Record 41 of Set 11 | sahuaripa
# Processing Record 42 of Set 11 | piterka
# Processing Record 43 of Set 11 | duz
# City not found. Skipping...
# Processing Record 44 of Set 11 | shimoda
# Processing Record 45 of Set 11 | teguldet
# Processing Record 46 of Set 11 | vaasa
# Processing Record 47 of Set 11 | abu dhabi
# Processing Record 48 of Set 11 | sigayevo
# Processing Record 49 of Set 11 | junction city
# Processing Record 0 of Set 12 | sao joao da barra
# Processing Record 1 of Set 12 | buraydah
# Processing Record 2 of Set 12 | urla
# Processing Record 3 of Set 12 | huanren
# Processing Record 4 of Set 12 | boende
# Processing Record 5 of Set 12 | ucluelet
# Processing Record 6 of Set 12 | san pedro
# Processing Record 7 of Set 12 | la romana
# Processing Record 8 of Set 12 | tairua
# Processing Record 9 of Set 12 | atchison
# Processing Record 10 of Set 12 | cayenne
# Processing Record 11 of Set 12 | ngunguru
# Processing Record 12 of Set 12 | terrace bay
# Processing Record 13 of Set 12 | port lincoln
# Processing Record 14 of Set 12 | morro agudo
# Processing Record 15 of Set 12 | omboue
# Processing Record 16 of Set 12 | kitimat
# Processing Record 17 of Set 12 | olavarria
# Processing Record 18 of Set 12 | itaqui
# Processing Record 19 of Set 12 | chernyshevskiy
# Processing Record 20 of Set 12 | okakarara
# Processing Record 21 of Set 12 | novhorodka
# Processing Record 22 of Set 12 | gull lake
# Processing Record 23 of Set 12 | indiaroba
# Processing Record 24 of Set 12 | samarai
# Processing Record 25 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 26 of Set 12 | nemuro
# Processing Record 27 of Set 12 | law
# Processing Record 28 of Set 12 | caronport
# Processing Record 29 of Set 12 | sakai
# Processing Record 30 of Set 12 | storforshei
# Processing Record 31 of Set 12 | martapura
# Processing Record 32 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 12 | tevaitoa
# Processing Record 34 of Set 12 | batagay-alyta
# Processing Record 35 of Set 12 | baker city
# Processing Record 36 of Set 12 | san borja
# Processing Record 37 of Set 12 | mabaruma
# Processing Record 38 of Set 12 | chimoio
# Processing Record 39 of Set 12 | bandar-e lengeh
# Processing Record 40 of Set 12 | salalah
# Processing Record 41 of Set 12 | verkhniy landekh
# Processing Record 42 of Set 12 | guru har sahai
# Processing Record 43 of Set 12 | orlovskiy
# Processing Record 44 of Set 12 | longonjo
# Processing Record 45 of Set 12 | buin
# Processing Record 46 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 47 of Set 12 | tigil
# Processing Record 48 of Set 12 | vostok
# Processing Record 49 of Set 12 | sooke
# Processing Record 0 of Set 13 | sao jose da coroa grande
# Processing Record 1 of Set 13 | sfantu gheorghe
# Processing Record 2 of Set 13 | sumy
# Processing Record 3 of Set 13 | chekhov
# Processing Record 4 of Set 13 | siuna
# Processing Record 5 of Set 13 | tshikapa
# Processing Record 6 of Set 13 | hagi
# Processing Record 7 of Set 13 | nangomba
# Processing Record 8 of Set 13 | mountain home
# Processing Record 9 of Set 13 | walvis bay
# Processing Record 10 of Set 13 | codajas
# Processing Record 11 of Set 13 | tivaouane
# Processing Record 12 of Set 13 | torres
# Processing Record 13 of Set 13 | la ronge
# Processing Record 14 of Set 13 | toliary
# City not found. Skipping...
# (614, 9) Data Retrieval Complete

# %%
cities_df.head()
# Out:
#                     City      Lat       Lng Max Temp Humidity Cloudiness  \
# 0             morant bay  17.8815  -76.4093    28.73       70         27
# 1               portland  45.5234 -122.6762    17.11       83        100
# 2                batagay  67.6333  134.6333     4.01       97        100
# 3  los llanos de aridane  28.6585  -17.9182    23.86       91         75
# 4                   chuy -33.6971  -53.4616    15.41       73         15
#
#   Wind Speed Country        Date
# 0       4.82      JM  1663163341
# 1       0.45      US  1663163341
# 2       3.21      RU  1663163344
# 3       2.57      ES  1663163350
# 4       5.18      UY  1663163354

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert the data to numeric
numeric=["Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Date"]
cities_df[numeric]=cities_df[numeric].apply(pd.to_numeric, errors='coerce', axis=1)
# Drop any rows with missing data
clean_cities_df = cities_df.dropna()
# Export the city data into a .csv.
clean_cities_df.to_csv("../output_data/cities_df.csv")
clean_cities_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             morant bay  17.8815  -76.4093     28.73      70.0        27.0
# 1               portland  45.5234 -122.6762     17.11      83.0       100.0
# 2                batagay  67.6333  134.6333      4.01      97.0       100.0
# 3  los llanos de aridane  28.6585  -17.9182     23.86      91.0        75.0
# 4                   chuy -33.6971  -53.4616     15.41      73.0        15.0
#
#    Wind Speed Country          Date
# 0        4.82      JM  1.663163e+09
# 1        0.45      US  1.663163e+09
# 2        3.21      RU  1.663163e+09
# 3        2.57      ES  1.663163e+09
# 4        5.18      UY  1.663163e+09

# %%
#Summery statistics of dataframe
clean_cities_df.describe(exclude = 'object')
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  562.000000  562.000000  562.000000  562.000000  562.000000  562.000000
# mean    18.380236   17.741940   19.690587   69.690391   54.670819    3.676886
# std     33.979800   91.460625    9.311560   21.949144   40.086806    2.434157
# min    -54.800000 -175.200000   -2.320000    6.000000    0.000000    0.000000
# 25%    -10.075025  -61.764025   12.387500   61.000000   12.250000    1.857500
# 50%     18.550000   19.903500   21.680000   75.000000   59.500000    3.215000
# 75%     47.881850  100.349575   26.787500   85.750000   97.750000    5.140000
# max     78.218600  179.316700   43.080000  100.000000  100.000000   15.050000
#
#                Date
# count  5.620000e+02
# mean   1.663164e+09
# std    1.240433e+02
# min    1.663163e+09
# 25%    1.663163e+09
# 50%    1.663164e+09
# 75%    1.663164e+09
# max    1.663164e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
#cities_df["Humidity"] = pd.to_numeric(cities_df["Humidity"])
humidity100 = clean_cities_df.loc[clean_cities_df["Humidity"] > 100].index
humidity100
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_cities_df = cities_df.drop(index = humidity100, inplace=False)
clean_cities_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             morant bay  17.8815  -76.4093     28.73      70.0        27.0
# 1               portland  45.5234 -122.6762     17.11      83.0       100.0
# 2                batagay  67.6333  134.6333      4.01      97.0       100.0
# 3  los llanos de aridane  28.6585  -17.9182     23.86      91.0        75.0
# 4                   chuy -33.6971  -53.4616     15.41      73.0        15.0
#
#    Wind Speed Country          Date
# 0        4.82      JM  1.663163e+09
# 1        0.45      US  1.663163e+09
# 2        3.21      RU  1.663163e+09
# 3        2.57      ES  1.663163e+09
# 4        5.18      UY  1.663163e+09

# %% [markdown]
# ## Plotting the Data
# * Use proper labelling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Latitude vs. Temperature Plot
plt.scatter(clean_cities_df["Lat"], clean_cities_df["Max Temp"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs. Max Temperature (12/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig("../images/Lat_vs_Temp.png")
plt.show()

# %% [markdown]
# This plot shows Latitude vs. todays Maximum Temperature of cities Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Latitude vs. Humidity Plot
plt.scatter(clean_cities_df["Lat"], clean_cities_df["Humidity"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs. Humidity (12/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.savefig("../images/Lat_vs_Humidity.png")

# %% [markdown]
# This plot shows todays Humidity of the cities on Lattitude range

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Latitude vs. Cloudiness Plot
plt.scatter(clean_cities_df["Lat"], clean_cities_df["Cloudiness"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs. Cloudiness (12/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.savefig("../images/Lat_vs_Cloudiness.png")

# %% [markdown]
# This plot shows Todays cloudiness of the cities in the Lattitude range

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Latitude vs. Wind Speed Plot
plt.scatter(clean_cities_df["Lat"], clean_cities_df["Wind Speed"], marker="o", facecolors="blue", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs. Wind Speed (12/01/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.savefig("../images/Lat_vs_WindSpeed.png")

# %% [markdown]
# This plot shows Todays Wind Speed of the cities in the Lattitude range

# %% [markdown]
# ## Linear Regression

# %%
#Northern Hemisphere DataFrame
northern_hemisphere = clean_cities_df.loc[clean_cities_df["Lat"] >= 0]

#Southern Hemisphere DataFrame
southern_hemisphere = clean_cities_df.loc[clean_cities_df["Lat"] < 0]

# %% [markdown]
# ###  Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.savefig("../images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

# %% [markdown]
# This plot shows Negetive corelation between Latitude and Max Temperature of Northern Hemisphere cities

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Max Temp vs. Latitude Linear Regression
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-45,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.savefig("../images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

# %% [markdown]
# This plot shows Positive corelation between Latitude and Max Temperature of Southern Hemisphere cities

# %% [markdown]
# ### Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,60),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.savefig("../images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# This plot shows No corelation between Latitude and Humidity of Northern Hemisphere cities

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.savefig("../images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# This plot shows No corelation between Latitude and Humidity of Southern Hemisphere cities

# %% [markdown]
# ### Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("../Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.savefig("../images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# This plot shows very weak positive corelation between Latitude and Cloudiness of Northern Hemisphere cities

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,60),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.savefig("../images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")

# %% [markdown]
# This plot shows positive corelation between Latitude and Cloudiness of Southern Hemisphere cities

# %% [markdown]
# ### Wind Speed (m/s) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = northern_hemisphere["Lat"]
y_values = northern_hemisphere["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,13),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.savefig("../images/Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")

# %% [markdown]
# This plot shows no corelation between Latitude and Wind Speed of Northern Hemisphere cities

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = southern_hemisphere["Lat"]
y_values = southern_hemisphere["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values, regress_values,"r-")
plt.annotate(line_eq,(-20,10),fontsize=15,color="red")
#plt.text(str(line_eq), loc = 0)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.savefig("../images/Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")

# %% [markdown]
# This plot shows No corelation between Latitude and Wind Speed of Southern Hemisphere cities

# %% [markdown]
# Analysis:
# 1. Weather becomes warmer as we approach the equater. From the plot, the northern hemispher seems to be slightly warmer.
# 2. There is not much relationship between latitude and wind speed.
# 3. There is not much relationship between latitude and cloudiness.
# 4. There is not much relationship between latitude and humidity.
